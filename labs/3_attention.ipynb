# %% [markdown]
# <a href="https://colab.research.google.com/github/vidaldominguez/uimp_deep_learning/blob/main/labs/3_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mecanismos de atención
#
# En este notebook, exploraremos cómo resolver un problema de análisis de sentimientos utilizando mecanismos de **self-attention**.
#
# El mecanismo de self-attention permite que cada elemento de una secuencia preste atención a otros elementos de la misma secuencia. Esto es útil para capturar dependencias a **largo plazo** a diferencia de las redes recurrentes tradicionales.
#
# Además, a diferencia de las redes LSTM o GRU, estas son **altamente paralelizables** dado que permiten tratar cada elemento de la secuencia de forma individual.

# %% [markdown]
# ## Conjunto de datos
#
# Utilizaremos un conjunto de datos pensado para la tarea de análisis de sentimientos. En este caso hemos optado por un conjunto de twits escritos en inglés, los cuales ya vienen etiquetados en tres clases:
# * Positive
# * Neutral
# * Negative

# %%
import pandas as pd
data_url = "https://raw.githubusercontent.com/pablo-pnunez/datasets/master/texto/sentiment_analysis_twitter.csv"
twitter_data = pd.read_csv(data_url)
tweets, tweets_sentiment = twitter_data["text"].str.strip().values, twitter_data["sentiment"].values

# %% [markdown]
# ### Preprocesar texto
#
# Normalmente los conjuntos de datos contienen errores o elementos no deseados, en esta parte los eliminaremos.
#
# Algunos ejemplos típicos son los números, los saltos de línea `\n` o los tabuladores `\t`.
#
# En esta parte separaremos además las entradas y salidas esperadas del modelo.

# %%
! pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0

# %%
import re
import time
import nltk
from unidecode import unidecode

x_data = []
y_data = []

for idx, tweet in enumerate(tweets):
    try:
        # Eliminar saltos de línea y retornos de carro
        tweet = re.sub(r'[\n\r]+', ' ', tweet)
        # Eliminar acentos utilizando la librería unidecode
        tweet = unidecode(tweet)
        # Pasar a minúsculas y eliminar resto de caracteres extraños (dos puntos, punto y coma, números...)
        tweet = re.sub(r'[^a-z\s]', '', tweet.lower())
        # Eliminamos más de un espacio
        tweet = re.sub(r'(\s)+', ' ', tweet)
        # Filtrar secuencias de 1 palabra o menos
        if len(tweet.split()) > 1:
            x_data.append(tweet)
            y_data.append(tweets_sentiment[idx])
    except:
        print(f"Error con el ejemplo {idx}, no se añade.")
# Out:
# Error con el ejemplo 314, no se añade.

# %% [markdown]
# ### Obtener vocabulario
#
# Una vez tenemos todas las frases, para codificar cada una de las palabras del texto es necesario obtener el llamado `corpus` o `vocabulario`. Este nos sirve para saber que palabras únicas (sin repetición) aparecen en nuestro texto, lo cual es útil para asignar un índice a cada una. Como verás, en este caso asignamos el índice en función de la frecuencia de aparición, por tanto, la palabra más frecuente tendrá el índice más bajo.
#
# Como recordarás, nuestro objetivo es que, dado un texto de máximo 5 palabras, el modelo entrenado sea capaz de continuar la frase hasta que decida finalizarla. Para lograrlo tenemos que tener en cuenta varios escenarios:
# * ¿Y si nos dan menos de 5 palabras?
# * ¿Como hacemos para detectar que la palabra generada por el modelo es la última de la frase? ¿Y la primera?
# * ¿Y si nos dan palabras fuera del vocabulario?
#
# Para solventar estos problemas, vamos a añadir dos palabras nuevas o `tokens` nuevos a nuestro vocabulario:
# * **\<pad\>**: Token que representa *padding*, es decir, si nos dan menos de 5 palabras, rellenaremos las que falten con este padding.
# * **\<unk\>**: Token que representa *unknown*, es decir, palabra desconocida (fuera del vocabulario).
# * **\<eos\>**: Token que representa *end-of-sequence*, es decir, fin de secuencia. Si el modelo predice este token, sabremos que ya se acabó la frase y podemos detener la generación.
# * **\<sos\>**: Token que representa *start-of-sequence*, es decir, comienzo de secuencia.

# %%
from collections import Counter

# Crear una lista con todas las palabras del texto
words = " ".join(x_data).split()
# Obtener el corpus del texto (todas las palabras que aparecen y su frecuencia)
word_counts = Counter(words)
# Filtrar palabras que aparecen menos de 5 veces, dado que no aportan mucho
word_counts = {word: count for word, count in word_counts.items() if count >=5}
# Ordenamos el corpus por frecuencia
word_counts = dict(sorted(word_counts.items(), key=lambda x: x[1], reverse=True))
# Extraemos solo las claves del diccionario anterior para crear el corpus
vocab = list(word_counts.keys())
# Añadimos tokens especiales <pad> (padding) y <unk> (unknown)
vocab = ["<pad>", "<unk>", "<sos>", "<eos>"] + vocab
# Generamos un diccionario (y su inverso) donde asignamos un id a cada palabra según su frecuencia.
# La palabra más frecuente será la 1. El 0 lo dejamos para el padding
word_to_ix = {word: i for i, word in enumerate(vocab)}
ix_to_word = {i: word for i, word in enumerate(vocab)}
vocab_size = len(vocab)

print(f'Tamaño del vocabulario: {vocab_size}')
print(f'Word to Index mapping: {word_to_ix}')
# Out:
# Tamaño del vocabulario: 4756
# Word to Index mapping: {'<pad>': 0, '<unk>': 1, '<sos>': 2, '<eos>': 3, 'i': 4, 'to': 5, 'the': 6, 'a': 7, 'my': 8, 'and': 9, 'you': 10, 'it': 11, 'is': 12, 'in': 13, 'for': 14, 'of': 15, 'im': 16, 'on': 17, 'me': 18, 'have': 19, 'so': 20, 'that': 21, 'but': 22, 'just': 23, 'with': 24, 'day': 25, 'its': 26, 'be': 27, 'at': 28, 'not': 29, 'was': 30, 'all': 31, 'good': 32, 'this': 33, 'now': 34, 'out': 35, 'up': 36, 'get': 37, 'are': 38, 'like': 39, 'no': 40, 'go': 41, 'dont': 42, 'your': 43, 'do': 44, 'love': 45, 'too': 46, 'work': 47, 'got': 48, 'going': 49, 'today': 50, 'cant': 51, 'from': 52, 'happy': 53, 'one': 54, 'am': 55, 'lol': 56, 'know': 57, 'time': 58, 'u': 59, 'what': 60, 'really': 61, 'will': 62, 'back': 63, 'about': 64, 'we': 65, 'had': 66, 'can': 67, 'see': 68, 'there': 69, 'if': 70, 'some': 71, 'well': 72, 'night': 73, 'new': 74, 'want': 75, 'think': 76, 'home': 77, 'as': 78, 'mothers': 79, 'how': 80, 'still': 81, 'much': 82, 'when': 83, 'oh': 84, 'more': 85, 'they': 86, 'off': 87, 'thanks': 88, 'an': 89, 'here': 90, 'miss': 91, 'great': 92, 'last': 93, 'has': 94, 'hope': 95, 'need': 96, 'thats': 97, 'been': 98, 'haha': 99, 'morning': 100, 'her': 101, 'ill': 102, 'feel': 103, 'then': 104, 'fun': 105, 'or': 106, 'would': 107, 'twitter': 108, 'tomorrow': 109, 'only': 110, 'wish': 111, 'again': 112, 'sad': 113, 'why': 114, 'he': 115, 'sorry': 116, 'bad': 117, 'didnt': 118, 'right': 119, 'tonight': 120, 'by': 121, 'were': 122, 'very': 123, 'make': 124, 'did': 125, 'gonna': 126, 'nice': 127, 'them': 128, 'though': 129, 'better': 130, 'she': 131, 'ive': 132, 'week': 133, 'yeah': 134, 'should': 135, 'sleep': 136, 'could': 137, 'way': 138, 'come': 139, 'over': 140, 'getting': 141, 'weekend': 142, 'bed': 143, 'people': 144, 'next': 145, 'youre': 146, 'watching': 147, 'school': 148, 'him': 149, 'wait': 150, 'days': 151, 'hate': 152, 'after': 153, 'awesome': 154, 'say': 155, 'best': 156, 'even': 157, 'never': 158, 'thing': 159, 'hey': 160, 'having': 161, 'little': 162, 'down': 163, 'yes': 164, 'being': 165, 'long': 166, 'soon': 167, 'wont': 168, 'working': 169, 'show': 170, 'thank': 171, 'any': 172, 'his': 173, 'ok': 174, 'who': 175, 'than': 176, 'mom': 177, 'sure': 178, 'first': 179, 'take': 180, 'cool': 181, 'look': 182, 'doing': 183, 'done': 184, 'sick': 185, 'our': 186, 'because': 187, 'friends': 188, 'life': 189, 'may': 190, 'everyone': 191, 'always': 192, 'ur': 193, 'tired': 194, 'guys': 195, 'feeling': 196, 'another': 197, 'hours': 198, 'already': 199, 'wanna': 200, 'please': 201, 'doesnt': 202, 'us': 203, 'movie': 204, 'made': 205, 'phone': 206, 'where': 207, 'x': 208, 'something': 209, 'ever': 210, 'find': 211, 'house': 212, 'man': 213, 'watch': 214, 'trying': 215, 'before': 216, 'old': 217, 'ready': 218, 'yet': 219, 'yay': 220, 'pretty': 221, 'into': 222, 'looking': 223, 'went': 224, 'left': 225, 'finally': 226, 'friday': 227, 'girl': 228, 'maybe': 229, 'live': 230, 'guess': 231, 'let': 232, 'same': 233, 'thought': 234, 'sucks': 235, 'away': 236, 'follow': 237, 'year': 238, 'amazing': 239, 'looks': 240, 'big': 241, 'bit': 242, 'also': 243, 'those': 244, 'missed': 245, 'other': 246, 'friend': 247, 'things': 248, 'someone': 249, 'keep': 250, 'monday': 251, 'while': 252, 'omg': 253, 'wow': 254, 'said': 255, 'saw': 256, 'two': 257, 'try': 258, 'hear': 259, 'star': 260, 'actually': 261, 'early': 262, 'nothing': 263, 'hot': 264, 'th': 265, 'tweet': 266, 'ugh': 267, 'hard': 268, 'start': 269, 'later': 270, 'hes': 271, 'tell': 272, 'bored': 273, 'glad': 274, 'n': 275, 'job': 276, 'until': 277, 'world': 278, 'such': 279, 'ya': 280, 'baby': 281, 'song': 282, 'id': 283, 'birthday': 284, 'havent': 285, 'car': 286, 'hi': 287, 'gone': 288, 'since': 289, 'around': 290, 'lost': 291, 'call': 292, 'play': 293, 'coming': 294, 'read': 295, 'makes': 296, 'check': 297, 'yesterday': 298, 'head': 299, 'sun': 300, 'till': 301, 'late': 302, 'excited': 303, 'myself': 304, 'rain': 305, 'isnt': 306, 'god': 307, 'found': 308, 's': 309, 'lot': ...

# %% [markdown]
# ### Crear dataset
# Una vez tenemos nuestro conjunto limpio y analizado, podemos crear los ejemplos con los que alimentaremos nuestro modelo.
#
# En este caso simplemente tendremos que buscar la frase de mayor longitud y crear todos los vectores de ese tamaño rellenando con padding.
#
# Tendremos que crear ademas las máscaras y los vectores de salida.

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
# Generar dataset completo
def generate_dataset(sentences, labels, word_to_ix, seq_length, y_map):
    # Para cada frase, generar los ejemplos
    x_data = []
    mask_data = []
    y_data = []

    for sentence, label in zip(sentences, labels):
        unk_index = word_to_ix["<unk>"]
        words = sentence.split()

        # Crear la secuencia de entrada
        seq_in = ['<pad>'] * (seq_length - len(words)) + words
        seq_in_indices = [word_to_ix.get(word, unk_index) for word in seq_in]
        x_data.append(seq_in_indices)

        # Creamos la máscara de padding
        mask = [1 if word != '<pad>' else 0 for word in seq_in]
        mask_data.append(mask)
        y_data.append(y_map[label])

    return tf.data.Dataset.from_tensor_slices(((x_data, mask_data), y_data))

# Dividir el dataset en entrenamiento, validación y prueba (80%,10%,10%)
sentences_train, sentences_test, labels_train, labels_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
sentences_val, sentences_test, labels_val, labels_test = train_test_split(sentences_test, labels_test, test_size=0.5, random_state=42)

# Definir parámetros y datos
max_seq_length = max([len(s.split(" ")) for s in x_data])
y_map = {"positive":0, "neutral":1, "negative":2}
batch_size = 1024

# Generar dataset
train_dataset = generate_dataset(sentences_train, labels_train, word_to_ix, max_seq_length, y_map).batch(batch_size)
val_dataset = generate_dataset(sentences_val, labels_val, word_to_ix, max_seq_length, y_map).batch(batch_size)
test_dataset = generate_dataset(sentences_test, labels_test, word_to_ix, max_seq_length, y_map).batch(batch_size)

# %% [markdown]
# ## 4.2.3. - Modelo
# Para este problema crearemos el modelo más sencillo posible:
# * **Capa Embedding**: Para cada elemento de la entrada, aprenderá un embedding que lo representará en un espacio de dimensión `embed_size`.
# * **Capa MultiheadAttention**: Esta capa permite al modelo enfocarse en diferentes partes de la secuencia de entrada simultáneamente. Cada "cabeza" en la atención múltiple (multi-head) puede capturar distintos patrones de relación entre los elementos de la secuencia.
#     * En la capa LSTM de la práctica anterior, el último elemento de la secuencia de salida contiene información de toda la secuencia, **en este caso no**.
#     * El número de heads se configura mediante `num_heads`.
# * **Capa Linear**: Proyecta el vector del último elemento de la salida de la LSTM en un espacio de tamaño `output_size`. En este caso `output_size` es igual al tamaño del vocabulario dado que estamos intentando resolver un problema de multi-clasificación.
#
# Nótese que no aplicamos la función `softmax` dado que esta se aplica internamente en la `CrossEntropyLoss`.

# %%
from tensorflow.keras import layers, Model, Input

# Hiperparámetros del modelo
embed_size = 32
num_heads = 1  # Número de cabezas de atención
hidden_size = 16
output_size = 3

num_epochs = 100
learning_rate = 0.0005

# Definir el modelo usando la API funcional
input_seq = Input(shape=(max_seq_length,), dtype=tf.int32, name='input_seq')
input_mask = Input(shape=(max_seq_length,), dtype=tf.int32, name='input_mask')

# Esta parte adapta la máscara a lo requerido por la capa attention
expanded_mask = layers.Lambda(lambda x: tf.repeat(tf.expand_dims(x, axis=1), max_seq_length, axis=1))(input_mask)

embedding_layer = layers.Embedding(input_dim=vocab_size, output_dim=embed_size, input_length=max_seq_length)(input_seq)
dropout_1 = layers.Dropout(.5)(embedding_layer)
attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=hidden_size)(dropout_1, dropout_1, attention_mask=expanded_mask)
dropout_2 = layers.Dropout(.5)(attention_output)
flatten_output = layers.GlobalAveragePooling1D()(dropout_2)
output_layer = layers.Dense(output_size, activation="softmax")(flatten_output)
model = Model(inputs=[input_seq, input_mask], outputs=output_layer)

# Compilar el modelo (necesario en TensorFlow/Keras)
model.compile(optimizer=tf.optimizers.Adam(learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Mostrar resumen del modelo
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_seq           │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 32, 32)    │    152,192 │ input_seq[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_mask          │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32, 32)    │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 32, 32)    │          0 │ input_mask[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 32)    │      2,128 │ dropout[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ dropout[0][0],    │
# │                     │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ dropout_2[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │         99 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 154,419 (603.20 KB)
#  Trainable params: 154,419 (603.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entrenamiento

# %%
history = model.fit(train_dataset, validation_data=val_dataset, epochs=num_epochs)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.3985 - loss: 1.0922 - val_accuracy: 0.4038 - val_loss: 1.0848
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.4068 - loss: 1.0785 - val_accuracy: 0.4132 - val_loss: 1.0697
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.4426 - loss: 1.0552 - val_accuracy: 0.4850 - val_loss: 1.0360
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.5092 - loss: 1.0023 - val_accuracy: 0.5293 - val_loss: 0.9629
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.5424 - loss: 0.9315 - val_accuracy: 0.5416 - val_loss: 0.9106
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.5624 - loss: 0.8920 - val_accuracy: 0.5796 - val_loss: 0.8796
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.6007 - loss: 0.8568 - val_accuracy: 0.6118 - val_loss: 0.8428
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6352 - loss: 0.8121 - val_accuracy: 0.6317 - val_loss: 0.7996
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.6626 - loss: 0.7694 - val_accuracy: 0.6473 - val_loss: 0.7715
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.6775 - loss: 0.7401 - val_accuracy: 0.6573 - val_loss: 0.7553
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.6903 - loss: 0.7169 - val_accuracy: 0.6625 - val_loss: 0.7443
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6997 - loss: 0.7014 - val_accuracy: 0.6700 - val_loss: 0.7368
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7077 - loss: 0.6847 - val_accuracy: 0.6720 - val_loss: 0.7330
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7151 - loss: 0.6706 - val_accuracy: 0.6730 - val_loss: 0.7291
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7209 - loss: 0.6603 - val_accuracy: 0.6717 - val_loss: 0.7272
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7255 - loss: 0.6505 - val_accuracy: 0.6707 - val_loss: 0.7270
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.7330 - loss: 0.6382 - val_accuracy: 0.6678 - val_loss: 0.7276
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.7350 - loss: 0.6326 - val_accuracy: 0.6674 - val_loss: 0.7282
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.7424 - loss: 0.6231 - val_accuracy: 0.6704 - val_loss: 0.7297
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.7426 - loss: 0.6176 - val_accuracy: 0.6713 - val_loss: 0.7312
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.7479 - loss: 0.6073 - val_accuracy: 0.6749 - val_loss: 0.7340
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7512 - loss: 0.6018 - val_accuracy: 0.6726 - val_loss: 0.7373
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7529 - loss: 0.5963 - val_accuracy: 0.6730 - val_loss: 0.7403
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7564 - loss: 0.5900 - val_accuracy: 0.6713 - val_loss: 0.7439
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.7595 - loss: 0.5831 - val_accuracy: 0.6713 - val_loss: 0.7484
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.7621 - loss: 0.5799 - val_accuracy: 0.6707 - val_loss: 0.7521
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.7607 - loss: 0.5784 - val_accuracy: 0.6704 - val_loss: 0.7550
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.7635 - loss: 0.5719 - val_accuracy: 0.6723 - val_loss: 0.7598
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7654 - loss: 0.5718 - val_accuracy: 0.6678 - val_loss: 0.7624
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7664 - loss: 0.5666 - val_accuracy: 0.6645 - val_loss: 0.7683
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7685 - loss: 0.5602 - val_accuracy: 0.6645 - val_loss: 0.7727
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.7708 - loss: 0.5603 - val_accuracy: 0.6642 - val_loss: 0.7781
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7743 - loss: 0.5547 - val_accuracy: 0.6619 - val_loss: 0.7831
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.7727 - loss: 0.5527 - val_accuracy: 0.6645 - val_loss: 0.7875
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7752 - loss: 0.5492 - val_accuracy: 0.6619 - val_loss: 0.7927
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.7768 - loss: 0.5478 - val_accuracy: 0.6593 - val_loss: 0.7975
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7791 - loss: 0.5421 - val_accuracy: 0.6583 - val_loss: 0.8045
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.7762 - loss: 0.5468 - val_accuracy: 0.6586 - val_loss: 0.8063
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.7769 - loss: 0.5426 - val_accuracy: 0.6557 - val_loss: 0.8124
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.7815 - loss: 0.5367 - val_accuracy: 0.6586 - val_loss: 0.8198
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.7816 - loss: 0.5352 - val_accuracy: 0.6586 - val_loss: 0.8248
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7828 - loss: 0.5340 - val_accuracy: 0.6583 - val_loss: 0.8268
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7805 - loss: 0.5295 - val_accuracy: 0.6573 - val_loss: 0.8321
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.7856 - loss: 0.5279 - val_accuracy: 0.6564 - val_loss: 0.8374
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7842 - loss: 0.5256 - val_accuracy: 0.6554 - val_loss: 0.8424
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7841 - loss: 0.5251 - val_accuracy: 0.6547 - val_loss: 0.8488
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.7861 - loss: 0.5250 - val_accuracy: 0.6538 - val_loss: 0.8511
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.7884 - loss: 0.5229 - val_accuracy: 0.6541 - val_loss: 0.8571
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7862 - loss: 0.5198 - val_accuracy: 0.6521 - val_loss: 0.8608
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7884 - loss: 0.5220 - val_accuracy: 0.6531 - val_loss: 0.8662
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7888 - loss: 0.5173 - val_accuracy: 0.6525 - val_loss: 0.8704
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7908 - loss: 0.5157 - val_accuracy: 0.6518 - val_loss: 0.8754
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7937 - loss: 0.5112 - val_accuracy: 0.6518 - val_loss: 0.8827
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7892 - loss: 0.5107 - val_accuracy: 0.6518 - val_loss: 0.8852
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7906 - loss: 0.5132 - val_accuracy: 0.6521 - val_loss: 0.8866
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7909 - loss: 0.5094 - val_accuracy: 0.6505 - val_loss: 0.8946
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7906 - loss: 0.5111 - val_accuracy: 0.6515 - val_loss: 0.8984
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.7928 - loss: 0.5062 - val_accuracy: 0.6518 - val_loss: 0.9041
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7909 - loss: 0.5090 - val_accuracy: 0.6512 - val_loss: 0.9028
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7928 - loss: 0.5088 - val_accuracy: 0.6502 - val_loss: 0.9129
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.7954 - loss: 0.5068 - val_accuracy: 0.6499 - val_loss: 0.9144
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.7964 - loss: 0.5064 - val_accuracy: 0.6512 - val_loss: 0.9181
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7940 - loss: 0.5070 - val_accuracy: 0.6492 - val_loss: 0.9222
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.7976 - loss: 0.4975 - val_accuracy: 0.6486 - val_loss: 0.9284
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.7951 - loss: 0.5021 - val_accuracy: 0.6486 - val_loss: 0.9353
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7948 - loss: 0.5036 - val_accuracy: 0.6492 - val_loss: 0.9355
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7965 - loss: 0.5006 - val_accuracy: 0.6492 - val_loss: 0.9368
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.7957 - loss: 0.4979 - val_accuracy: 0.6479 - val_loss: 0.9424
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.7951 - loss: 0.5006 - val_accuracy: 0.6469 - val_loss: 0.9461
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.7966 - loss: 0.5000 - val_accuracy: 0.6453 - val_loss: 0.9531
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7986 - loss: 0.4968 - val_accuracy: 0.6434 - val_loss: 0.9568
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.7945 - loss: 0.5003 - val_accuracy: 0.6450 - val_loss: 0.9570
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.7985 - loss: 0.4974 - val_accuracy: 0.6453 - val_loss: 0.9580
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7988 - loss: 0.4942 - val_accuracy: 0.6440 - val_loss: 0.9662
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7997 - loss: 0.4932 - val_accuracy: 0.6437 - val_loss: 0.9715
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7975 - loss: 0.4946 - val_accuracy: 0.6460 - val_loss: 0.9800
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.8008 - loss: 0.4900 - val_accuracy: 0.6460 - val_loss: 0.9826
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8004 - loss: 0.4904 - val_accuracy: 0.6443 - val_loss: 0.9810
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7988 - loss: 0.4919 - val_accuracy: 0.6434 - val_loss: 0.9836
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7992 - loss: 0.4900 - val_accuracy: 0.6440 - val_loss: 0.9853
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7988 - loss: 0.4949 - val_accuracy: 0.6437 - val_loss: 0.9899
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8003 - loss: 0.4931 - val_accuracy: 0.6463 - val_loss: 0.9951
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7997 - loss: 0.4915 - val_accuracy: 0.6453 - val_loss: 0.9971
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8011 - loss: 0.4885 - val_accuracy: 0.6463 - val_loss: 1.0029
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8031 - loss: 0.4870 - val_accuracy: 0.6450 - val_loss: 1.0074
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8006 - loss: 0.4890 - val_accuracy: 0.6473 - val_loss: 1.0118
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8004 - loss: 0.4890 - val_accuracy: 0.6476 - val_loss: 1.0157
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8016 - loss: 0.4871 - val_accuracy: 0.6466 - val_loss: 1.0220
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8002 - loss: 0.4866 - val_accuracy: 0.6469 - val_loss: 1.0184
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8002 - loss: 0.4906 - val_accuracy: 0.6443 - val_loss: 1.0206
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.8032 - loss: 0.4859 - val_accuracy: 0.6430 - val_loss: 1.0231
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.8024 - loss: 0.4813 - val_accuracy: 0.6427 - val_loss: 1.0341
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8016 - loss: 0.4863 - val_accuracy: 0.6430 - val_loss: 1.0383
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8029 - loss: 0.4886 - val_accuracy: 0.6430 - val_loss: 1.0349
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8053 - loss: 0.4835 - val_accuracy: 0.6450 - val_loss: 1.0323
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8013 - loss: 0.4841 - val_accuracy: 0.6421 - val_loss: 1.0388
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8035 - loss: 0.4864 - val_accuracy: 0.6427 - val_loss: 1.0440
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8014 - loss: 0.4847 - val_accuracy: 0.6430 - val_loss: 1.0488
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8042 - loss: 0.4843 - val_accuracy: 0.6440 - val_loss: 1.0554
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8021 - loss: 0.4842 - val_accuracy: 0.6453 - val_loss: 1.0616

# %% [markdown]
# ## Evaluación

# %%
# Definir la función de predicción
def predict(model, text, word_to_ix, ix_to_word, seq_length, y_map):
    # Preprocesar el texto de entrada
    text = unidecode(text).lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()

    # Convertir palabras a índices
    input_sequence = [word_to_ix.get(word, word_to_ix['<pad>']) for word in words]
    input_sequence = input_sequence[-seq_length:]  # Tomar solo las últimas seq_length palabras
    input_sequence = [word_to_ix['<pad>']] * (seq_length - len(input_sequence)) + input_sequence


    # Convertir la secuencia y la máscara a tensores
    input_tensor = tf.constant([input_sequence], dtype=tf.int64)
    mask_tensor = tf.cast(input_tensor!=0, tf.int32)


    output = model([input_tensor, mask_tensor], training=False)

    max_output = output.numpy().argmax()
    max_pred = output.numpy().max()

    print(f"The text '{text}' is {list(y_map.keys())[max_output]} [{max_pred*100:0.0f}%]")

# Ejemplo de texto de entrada
input_text = "This product is lovely"
predicted_text = predict(model, input_text, word_to_ix, ix_to_word, max_seq_length, y_map)
# Out:
# The text 'this product is lovely' is positive [93%]
